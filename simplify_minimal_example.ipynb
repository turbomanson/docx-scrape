# %%
import docx
from simplify_docx import simplify

# %%
doc_path = './ExampleTestDoc.docx'

# read in a document 
my_doc = docx.Document(doc_path)

# coerce to JSON using the standard options
my_doc_as_json = simplify(my_doc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8f157dad6c0e> in <module>
#       5
#       6 # coerce to JSON using the standard options
# ----> 7 my_doc_as_json = simplify(my_doc)
#
# /anaconda3/envs/planning/lib/python3.7/site-packages/simplify_docx/__init__.py in simplify(doc, options)
#      31     __set_options__(_options)
#      32
# ---> 33     out = document(doc.element).to_json(doc, _options)
#      34
#      35     if _options.get("friendly-name", True):
#
# /anaconda3/envs/planning/lib/python3.7/site-packages/simplify_docx/elements/base.py in to_json(self, doc, options, super_iter)
#     104         out.update({
#     105                 "TYPE": self.__type__,
# --> 106                 "VALUE": [ elt.to_json(doc, options) for elt in self],
#     107                 })
#     108         return out
#
# ...
